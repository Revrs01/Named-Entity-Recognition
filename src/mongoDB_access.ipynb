# %%
import json
import pandas
import NER_tag_converter
import pymongo

# %%
aggregate_data = list()
# load dataframe
data = pandas.read_csv('../Datasets/self_create_datasets_with_diff_tags/Train_data_ner_tags.csv', encoding='utf-8')
# convert NER token number to NER tag
for i in range(len(data['Id'])):
    index = int(data['Id'][i])
    token = eval(data['Tokens'][i])
    tag = list()
    for j in eval(data['NER_tag'][i]):
        tag.append(NER_tag_converter.convert(j))
    # create dictionary for every index
    json_format = {'index': str(index), 'token': str(token), 'NER_tag': str(tag)}
    aggregate_data.append(json_format)
    # insert into mongoDB

# %%
password = ''
link_db = pymongo.MongoClient('mongodb+srv://philwu53:{}@clusterner.0wnlvev.mongodb.net/test'.format(password))

# %%
# access into specific table
mydb = link_db['mydatabase']  # database: mydatabase
mytable = mydb['table']  # collection: table
# insert all data into database
# mytable.insert_many(aggregate_data)

# %%
update_ner_tag = '''['B-GPE', 'I-GPE', 'I-GPE', 'B-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'I-ORG', 'O', 'O', 'O', 'B-DATE', 'I-DATE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE', 'O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATE', 'I-DATE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'B-DATE', 'I-DATE', 'I-DATE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATE', 'I-DATE', 'O', 'B-GPE', 'O', 'B-GPE', 'O', 'O', 'O', 'B-ORG', 'I-ORG', 'I-ORG', 'O', 'B-ORG', 'I-ORG', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'B-QUANTITY', 'I-QUANTITY', 'I-QUANTITY', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-QUANTITY', 'I-QUANTITY', 'I-QUANTITY', 'O', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'B-CARDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-GPE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORDINAL', 'I-ORDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ORDINAL', 'I-ORDINAL', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATE', 'I-DATE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-DATE', 'I-DATE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-PER', 'I-PER', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']'''

# %%
mytable.update_one({'index': '1'}, {'$set': {'NER_tag': update_ner_tag}})

for el in mytable.find({'index': '1'}, {'token': 0}):
    print(el)

# %%
print(mytable.estimated_document_count())
# Out:
# 9580

# %%
read_one = mytable.find({'index': '0'}, {'_id': 0})[0]
read_one['index'] = '9580'

mytable.insert_one(read_one)
print(mytable.estimated_document_count())
# Out:
# 9581

# %%
query = {'token': read_one['token']}
for i in mytable.find(query):
    print(i)
print(mytable.count_documents(query))
# Out:
# {'_id': ObjectId('6453bac76bb0448b2cfa1831'), 'index': '0', 'token': "['騎', '車', '在', '路', '上', '如', '果', '十', '多', '隻', '狗', '擋', '在', '路', '中', '央', '，', '相', '信', '沒', '有', '人', '敢', '騎', '過', '去', '。', '台', '南', '四', '鯤', '鯓', '上', '的', '一', '條', '道', '路', '出', '現', '十', '多', '隻', '狗', '群', '聚', '遊', '蕩', '，', '讓', '附', '近', '的', '居', '民', '沒', '人', '敢', '經', '過', '，', '狗', '群', '還', '會', '跑', '進', '周', '邊', '的', '社', '區', '裏', '，', '而', '養', '狗', '的', '婦', '人', '不', '讓', '動', '保', '處', '的', '人', '處', '理', '犬', '隻', '，', '也', '不', '關', '籠', '繫', '繩', '，', '真', '的', '讓', '居', '民', '很', '頭', '痛', '。', '民', '眾', '開', '車', '來', '到', '台', '南', '四', '鯤', '鯓', '，', '一', '間', '國', '小', '後', '方', '的', '這', '條', '道', '路', '，', '被', '路', '中', '央', '的', '景', '象', '嚇', '了', '一', '跳', '，', '擋', '了', '好', '幾', '十', '隻', '的', '狗', '，', '有', '的', '走', '來', '走', '去', '有', '的', '則', '躺', '在', '路', '中', '，', '車', '輛', '開', '過', '狗', '群', '的', '旁', '邊', '，', '躺', '在', '地', '上', '的', '狗', '完', '全', '不
# ...

# %%
mytable.delete_one({'index': '9580'})
print(mytable.count_documents(query))
# Out:
# 1

# %%
for i in link_db['NER']['News_Dataset'].find({'index':'0'}, {}):
    print(i)
# Out:
# {'_id': ObjectId('6453bac76bb0448b2cfa1831'), 'index': '0', 'token': "['騎', '車', '在', '路', '上', '如', '果', '十', '多', '隻', '狗', '擋', '在', '路', '中', '央', '，', '相', '信', '沒', '有', '人', '敢', '騎', '過', '去', '。', '台', '南', '四', '鯤', '鯓', '上', '的', '一', '條', '道', '路', '出', '現', '十', '多', '隻', '狗', '群', '聚', '遊', '蕩', '，', '讓', '附', '近', '的', '居', '民', '沒', '人', '敢', '經', '過', '，', '狗', '群', '還', '會', '跑', '進', '周', '邊', '的', '社', '區', '裏', '，', '而', '養', '狗', '的', '婦', '人', '不', '讓', '動', '保', '處', '的', '人', '處', '理', '犬', '隻', '，', '也', '不', '關', '籠', '繫', '繩', '，', '真', '的', '讓', '居', '民', '很', '頭', '痛', '。', '民', '眾', '開', '車', '來', '到', '台', '南', '四', '鯤', '鯓', '，', '一', '間', '國', '小', '後', '方', '的', '這', '條', '道', '路', '，', '被', '路', '中', '央', '的', '景', '象', '嚇', '了', '一', '跳', '，', '擋', '了', '好', '幾', '十', '隻', '的', '狗', '，', '有', '的', '走', '來', '走', '去', '有', '的', '則', '躺', '在', '路', '中', '，', '車', '輛', '開', '過', '狗', '群', '的', '旁', '邊', '，', '躺', '在', '地', '上', '的', '狗', '完', '全', '不
# ...
